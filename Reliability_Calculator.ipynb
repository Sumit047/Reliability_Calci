# %%
import pandas as pd
dfi=pd.read_csv(r'./files/input.csv')
dfi
# Out:
#     Sr Reason_of_failure Components_Failed  Number_of_Failure Time_Interval
# 0    1     Early failure             comp1                 26     0.00-4.00
# 1    2           reason1             comp2                 59       4.0-8.0
# 2    3           reason2             comp3                 36      8.0-12.0
# 3    4           reason3             comp4                 57     12.0-16.0
# 4    5           reason7             comp5                 33     16.0-20.0
# 5    6           reason4             comp6                 35     20.0-24.0
# 6    7           reason1             comp7                 29     24.0-28.0
# 7    8           reason2             comp8                 34     28.0-32.0
# 8    9           reason3             comp9                 14     32.0-36.0
# 9   10           reason2            comp10                 46     36.0-40.0
# 10  11           reason4             comp1                 32     40.0-44.0
# 11  12           reason5            comp12                 25     44.0-48.0
# 12  13           reason2            comp13                 19     48.0-52.0
# 13  14           reason3            comp14                 20     52.0-56.0
# 14  15           reason2             comp5                 18     56.0-60.0
# 15  16           reason4            comp16                 60     60.0-64.0
# 16  17           reason1            comp17                 18     64.0-68.0
# 17  18           reason6            comp18                 28     68.0-72.0
# 18  19           reason3            comp19                 20     72.0-76.0

# %%
import main
import pandas as pd
df=pd.read_csv(r'./files/output.csv')
df
# Out:
#     Sr. No. Reason_of_failure Components_Failed  Number_of_failures  \
# 0         1     Early failure             comp1                  26
# 1         2           reason1             comp2                  59
# 2         3           reason2             comp3                  36
# 3         4           reason3             comp4                  57
# 4         5           reason7             comp5                  33
# 5         6           reason4             comp6                  35
# 6         7           reason1             comp7                  29
# 7         8           reason2             comp8                  34
# 8         9           reason3             comp9                  14
# 9        10           reason2            comp10                  46
# 10       11           reason4             comp1                  32
# 11       12           reason5            comp12                  25
# 12       13           reason2            comp13                  19
# 13       14           reason3            comp14                  20
# 14       15           reason2             comp5                  18
# 15       16           reason4            comp16                  60
# 16       17           reason1            comp17                  18
# 17       18           reason6            comp18                  28
# 18       19           reason3            comp19                  20
#
#     Time_Interval  Reliability_Factor  Probability_of_Failure  Failure_Rate  \
# 0             0.0                0.96                    0.04        0.0109
# 1             4.0                0.86                    0.14        0.0266
# 2             8.0                0.80                    0.20        0.0178
# 3            12.0                0.71                    0.29        0.0310
# 4            16.0                0.65                    0.35        0.0199
# 5            20.0                0.60                    0.40        0.0230
# 6            24.0                0.55                    0.45        0.0208
# 7            28.0                0.49                    0.51        0.0268
# 8            32.0                0.47                    0.53        0.0119
# 9            36.0                0.39                    0.61        0.0437
# 10           40.0                0.34                    0.66        0.0357
# 11           44.0                0.30                    0.70        0.0320
# 12           48.0                0.27                    0.73        0.0274
# 13           52.0                0.24                    0.76        0.0325
# 14           56.0                0.21                    0.79        0.0333
# 15           60.0                0.11                    0.89        0.1562
# 16           64.0                0.08                    0.92        0.0789
# 17           68.0                0.03                    0.97        0.2059
# 18           72.0                0.00                    1.00        0.5000
#
#     Mean_Time_Between_Failures
# 0                     2.923077
# 1                     0.894118
# 2                     0.628099
# 3                     0.426966
# 4                     0.360190
# 5                     0.308943
# 6                     0.276364
# 7                     0.245955
# 8                     0.235294
# 9                     0.205962
# 10                    0.189526
# 11                    0.178404
# 12                    0.170787
# 13                    0.163441
# 14                    0.157350
# 15                    0.139963
# 16                    0.135472
# 17                    0.129032
# 18                    0.124795

# %% [markdown]
# # Prediction_Model

# %%
import main
pr=main.Predict

# %% [markdown]
#  Reliability Factor

# %%
pr.reliability_factor(1)
# Out:
# 0.93

# %% [markdown]
#  Failure rate

# %%
pr.failure_rate(4)
# Out:
# 0.016329346092504225

# %% [markdown]
# Probability Of Failure

# %%
pr.probability_of_failure(4)
# Out:
# 0.1314969241285033

# %% [markdown]
# Mean Time Betweeen Failures

# %%
pr=main.Predict
pr.mtbf(2)
# Out:
# 1.8086187897536008

# %% [markdown]
# # VISUALIZATION

# %%
vs=main.visualize
vs.reliability_factor.scatter_plot()
vs.reliability_factor.bar_graph()
vs.reliability_factor.pie_chart()

# %%
vs.failure_rate.scatter_plot()
vs.failure_rate.bar_graph()
vs.failure_rate.pie_chart()

# %%
vs.probability_of_failure.scatter_plot()
vs.probability_of_failure.bar_graph()
vs.probability_of_failure.pie_chart()

# %%
vs.mtbf.scatter_plot()
vs.mtbf.bar_graph()
vs.mtbf.pie_chart()

# %% [markdown]
# # Reason of failure

# %%
import filter
import pandas as pd
dff=pd.read_csv(r'./files/filtered.csv')
dff
# Out:
#   Reason_of_failure Components_Failed  Time_Interval  Failure_Rate  \
# 0           reason1             comp2            4.0        0.0266
# 1           reason2             comp3            8.0        0.0178
# 2           reason3             comp4           12.0        0.0310
# 3           reason7             comp5           16.0        0.0199
# 4           reason4             comp6           20.0        0.0230
# 5           reason2             comp8           28.0        0.0268
# 6           reason2            comp10           36.0        0.0437
# 7           reason4             comp1           40.0        0.0357
# 8           reason4            comp16           60.0        0.1562
#
#    Mean_Time_Between_Failures
# 0                    0.894118
# 1                    0.628099
# 2                    0.426966
# 3                    0.360190
# 4                    0.308943
# 5                    0.245955
# 6                    0.205962
# 7                    0.189526
# 8                    0.139963

# %%
import reason
# Out:
# reason2    5
# reason4    4
# reason1    1
# reason3    1
# reason7    1
# reason5    1
# Name: Reason_of_failure, dtype: int64

# %%
import components
# Out:
# comp10    2
# comp1     2
# comp2     1
# comp3     1
# comp4     1
# comp5     1
# comp6     1
# comp8     1
# comp16    1
# Name: Components_failed, dtype: int64

# %% [markdown]
# # Net Reliability Using Cronbach alpha

# %%
import pandas as pd
dfp=pd.read_csv(r'./files/product.csv')
dfp
# Out:
#     Sr_No  Item1  Item2  Item3  Item4  Item5
# 0       1      4      4      3      5      3
# 1       2      3      5      1      4      1
# 2       3      3      4      4      4      4
# 3       4      3      3      5      2      1
# 4       5      3      4      5      4      3
# 5       6      4      5      5      3      2
# 6       7      2      5      5      3      4
# 7       8      3      4      4      2      4
# 8       9      3      5      4      4      3
# 9      10      3      3      2      3      2
# 10     11      3      3      2      3      2
# 11     12      3      4      1      4      2
# 12     13      2      5      3      3      1
# 13     14      4      4      4      4      2
# 14     15      3      3      5      5      1
# 15     16      3      4      5      4      3
# 16     17      4      4      1      3      1
# 17     18      3      3      5      4      4
# 18     19      2      5      3      4      2
# 19     20      3      3      2      3      2

# %%
import Net_Reliability
# Out:
# 0.23186119873817032
# Rather Reliable
# Not Good
